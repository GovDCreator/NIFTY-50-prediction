# %%
# Standard data imports
import pandas as pd
import numpy as np
# Visualization 
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# Scikit-learn metrics, functions and models
from sklearn import metrics
import mplfinance as mpf

# %%
# Loading the CSV file from the file location dataset 
df0 = pd.read_csv('NIFTY 50-11-10-2020-to-11-10-2021.csv')
df1 = pd.read_csv('NIFTY 50-11-10-2021-to-11-10-2022.csv')
df2 = pd.read_csv('NIFTY 50-11-10-2022-to-11-10-2023.csv')
df3 = pd.read_csv('NIFTY 50-11-10-2023-to-11-10-2024.csv')
df4 = pd.read_csv('NIFTY 50-11-10-2024-to-11-10-2025.csv')
renaming_map = {
    'date ': 'date',
# Printing the over view of the raw data set
print(test_data.shape)
print(train_data.shape)
print(val_data.shape)
print(train_data.columns)
# Out:
# (249, 7)
# (872, 8)
# (125, 8)
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Shares Traded',
#        'Turnover (₹ Cr)', 'Date '],
#       dtype='object')

# %%
train_data['Date'] = pd.to_datetime(train_data['Date '])
# Out:
# <positron-console-cell-9>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# <positron-console-cell-9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_data.columns
# Out:
# Index(['Date ', 'Open ', 'High ', 'Low ', 'Close ', 'Shares Traded ',
#        'Turnover (₹ Cr)', 'Date'],
#       dtype='object')
